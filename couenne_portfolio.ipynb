# %%
import pandas as pd
import numpy as np
from __future__ import division
from pyomo.environ import *
import pickle
import time

# %% [markdown]
# Preprocessing

# %%
all_data=pd.read_csv('../data/Timeseries_data_SP500.csv')

all_data['DATE']=pd.to_datetime(all_data['DATE'])
all_data=all_data.rename(columns={'NAME':'name','DATE':'date','SEDOL':'sedol','SECTOR':'sector','BETA':'beta','ALPHA_SCORE':'as','BENCH_WEIGHT':'bw',"MCAP_Q":'mq'})
sedol_list=all_data['sedol'].unique().tolist()

date_list=list(set(list(all_data['date'])))
date_list.sort()

dic_data = {k: v for k, v in all_data.groupby('date')}

results_=pd.read_csv('../data/results_template.csv')
results_=results_.rename(columns={'DATE':'date','SEDOL':'sedol','WEIGHTS':'w','FOUR_WEEKLY_RETURN':'r'})
results_['date']=pd.to_datetime(results_['date'])
dic_results_={k: v for k, v in results_.groupby('date')}

dic_r_all={}
for i in date_list:
    rr={}
    for j,k in zip(list(dic_results_[i]['sedol']),list(dic_results_[i]['r'])):
        rr[j]=k
    dic_r_all[i]=rr

def preprocessing(date):
    
    using_dic = dic_data[pd.to_datetime(date)]
    using_dic['index']=list(using_dic.index)

    asset_list = []
    for i in using_dic["sedol"]:
        asset_list.append(i)


    dic_sedol_as = {using_dic["sedol"][i] : using_dic["as"][i] for i in using_dic.index}

    dic_bench = {using_dic["sedol"][i] : using_dic["bw"][i] for i in using_dic.index}

    dic_beta = {using_dic["sedol"][i] : using_dic["beta"][i] for i in using_dic.index}

    dic_sector = {using_dic["sector"][i] : [] for i in using_dic.index }

    dic_MCAP = {using_dic["mq"][i] : [] for i in using_dic.index}

    dic_aseet_MCAP = {using_dic["sedol"][i] : using_dic["mq"][i] for i in using_dic.index}
    
    dic_aseet_sector = {using_dic["sedol"][i] : using_dic["sector"][i] for i in using_dic.index}
    
    for i in using_dic.index:
        dic_sector[using_dic["sector"][i]].append(using_dic["sedol"][i])
        dic_MCAP[using_dic["mq"][i]].append(using_dic["sedol"][i])



    #risk:cov_mat
    date_str=str(date)[:10]
    risk_data=pd.read_csv('../data/Riskmodels/cov_mat_%s.csv'%(date_str))
    risk_sedol=risk_data['ROW_INDEX'].unique().tolist()
    risk_mat = np.zeros((len(risk_sedol),len(risk_sedol)))
    risk_mat[np.triu_indices(len(risk_sedol), 0)] = list(risk_data['VALUE'])
    irows,icols = np.triu_indices(len(risk_sedol),0)
    risk_mat[icols,irows]=risk_mat[irows,icols]
    #         return risk_data,risk_sedol,risk_mat

    
    alpha = []
    
    dic_risk_index = {}
    index_ri = 0

    for i in risk_sedol:
        dic_risk_index.update({i:index_ri})
        index_ri += 1
        alpha.append(-1*dic_sedol_as[i])

    dic_r={dic_results_[date]["sedol"][i] : dic_results_[date]["r"][i] for i in using_dic.index}

    return using_dic,asset_list,dic_sedol_as,dic_bench,dic_beta,dic_sector,dic_MCAP,risk_sedol,risk_mat,dic_r,alpha,dic_aseet_MCAP,dic_aseet_sector,dic_risk_index

# %% [markdown]
# Modeling (Nonlinear_QCQP)

# %%
############# Settings ##############
n=0  # month
date=date_list[n]
using_dic,NEW_stocks,dic_alpha,dic_bench,dic_beta,dic_sector,dic_MCAP,risk_sedol,risk_mat,dic_r,alpha,dic_aseet_MCAP,dic_aseet_sector,dic_risk_index=preprocessing(date)

omega={}
for i in NEW_stocks:
    omega[i]={}
    for j in NEW_stocks:
        omega[i][j]=risk_mat[NEW_stocks.index(i)][NEW_stocks.index(j)]

model = ConcreteModel()


############## set #################

model.I = Set(initialize = NEW_stocks)
model.J = Set(initialize = NEW_stocks)
model.S = Set(initialize = list(dic_sector.keys()))
model.K = Set(initialize = list(dic_MCAP.keys()))


############# Decision Variables ###############

model.d = Var([i for i in model.I], domain=Reals, bounds=(-0.05,0.05))
model.w = Var([i for i in model.I], domain=NonNegativeReals, bounds=(0,1))
model.y = Var([i for i in model.I], domain=Binary)


############# Constraints ##############

def constraint1(model , i) :
    return model.d[i] == model.w[i] - dic_bench[i]
model.con1 = Constraint(model.I, rule=constraint1)

def constraint4(model) :
    return sum(model.w[i] for i in model.I) == 1
model.con4 = Constraint(rule=constraint4)

def constraint6(model, s) :
    return -0.1 <= sum(model.d[i] for i in dic_sector[s]) <= 0.1 
model.con6 = Constraint(model.S, rule=constraint6)    

def constraint7(model, k) :
    return -0.1 <= sum(model.d[i] for i in dic_MCAP[k]) <= 0.1 
model.con7 = Constraint(model.K, rule=constraint7)    

def constraint8(model):
    return -0.1 <= sum(model.d[i]*dic_beta[i] for i in model.I) <= 0.1

def constraint9_1(model, i) :
    return model.y[i] >= model.w[i]
model.con9_1 = Constraint(model.I, rule=constraint9_1)    

def constraint9_2(model, i) :
    return model.y[i] <= model.w[i]+0.999
model.con9_2 = Constraint(model.I, rule=constraint9_2)    

def constraint9_3(model) :
    return 50 <= sum(model.y[i] for i in model.I) <= 70
model.con9_3 = Constraint(rule=constraint9_3)    

def constraint10(model) :
    return 0.6 <= 0.5 * sum(abs(model.d[i]) for i in model.I) <= 1.
model.con10 = Constraint(rule=constraint10)    

def constraint11(model) :
    return 0.0025 <= (sum(model.d[i]*omega[i][j]*model.d[j] for i in model.I for j in model.J)) <= 0.01
model.con11 = Constraint(rule=constraint11)   


############ Objective Function #############

def objective_rule(model):
    return sum(-model.d[i] * dic_alpha[i] for i in model.I) +sum(model.d[i]*omega[i][j]*model.d[j] for i in model.I for j in model.J) 


model.objective = Objective(rule=objective_rule, sense=minimize)

# %% [markdown]
# Solve (couenne)

# %%
######### Execute(Solve) ##########
start=time.time()
solver = SolverFactory('couenne', executable='./couenne')
solution = solver.solve(model,tee=True)
time = time.time() - start


######## Save Results #########

w = model.w.get_values()
d = model.d.get_values()
y = model.y.get_values()


with open('Results/T1(couenne).txt', 'wb') as f:
    pickle.dump(w, f)
    pickle.dump(d, f)
    pickle.dump(y, f)
    pickle.dump(solution, f)
    pickle.dump(time,f)
# Out:
# ############ Trial : 1 #############
# Couenne 0.5.6 -- an Open-Source solver for Mixed Integer Nonlinear Optimization
# Mailing list: couenne@list.coin-or.org
# Instructions: http://www.coin-or.org/Couenne
# couenne:
# ANALYSIS TEST: Reformulating problem: 13.8 seconds
# NLP0012I
#               Num      Status      Obj             It       time                 Location
# NLP0014I             1         OPT 0.0024845502      105 59.19317
# NLP0014I             2         OPT 0.0026787841       37 11.891635
# Couenne: new cutoff value 2.6787840688e-03 (108.152 seconds)
# Loaded instance "/tmp/tmpawsosxu8.pyomo.nl"
# Constraints:         1495
# Variables:           1476 (492 integer)
# Auxiliaries:        95892 (1 integer)
#
# Coin0506I Presolve 383012 (-493) rows, 96364 (-1004) columns and 1336291 (-1496) elements
# Clp0006I 0  Obj 0 Primal inf 64.346371 (495) Dual inf 1.0755131e+15 (96364)
# Clp0006I 1000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (1086)
# Clp0006I 2000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (6041)
# Clp0006I 3000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (1438)
# Clp0006I 4000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (7218)
# Clp0006I 5000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (1775)
# Clp0006I 6000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (1968)
# Clp0006I 7000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (2128)
# Clp0006I 8000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (9367)
# Clp0006I 9000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (10612)
# Clp0006I 10000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (11293)
# Clp0006I 11000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (2772)
# Clp0006I 12000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (2930)
# Clp0006I 13000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (12089)
# Clp0006I 14000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (12667)
# Clp0006I 15000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (3422)
# Clp0006I 16000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (3599)
# Clp0006I 17000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (3782)
# Clp0006I 18000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (4922)
# Clp0006I 19000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (4112)
# Clp0006I 20000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (17663)
# Clp0006I 21000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (16617)
# Clp0006I 22000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (18766)
# Clp0006I 23000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (7028)
# Clp0006I 24000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (18301)
# Clp0006I 25000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (5038)
# Clp0006I 26000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (5229)
# Clp0006I 27000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (5412)
# Clp0006I 28000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (9205)
# Clp0006I 29000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (5720)
# Clp0006I 30000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (23690)
# Clp0006I 31000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (24345)
# Clp0006I 32000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (6228)
# Clp0006I 33000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (6413)
# Clp0006I 34000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (6609)
# Clp0006I 35000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (16991)
# Clp0006I 36000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (27685)
# Clp0006I 37000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (7128)
# Clp0006I 38000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (7329)
# Clp0006I 39000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (29595)
# Clp0006I 40000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (30223)
# Clp0006I 41000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (7848)
# Clp0006I 42000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (8017)
# Clp0006I 43000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (29094)
# Clp0006I 44000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (32837)
# Clp0006I 45000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (20643)
# Clp0006I 46000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (34138)
# Clp0006I 47000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (8906)
# Clp0006I 48000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (9060)
# Clp0006I 49000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (9212)
# Clp0006I 50000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (9343)
# Clp0006I 51000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (21836)
# Clp0006I 52000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (9609)
# Clp0006I 53000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (22682)
# Clp0006I 54000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (38990)
# Clp0006I 55000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (10150)
# Clp0006I 56000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (10328)
# Clp0006I 57000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (36934)
# Clp0006I 58000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (10673)
# Clp0006I 59000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (10853)
# Clp0006I 60000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (11051)
# Clp0006I 61000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (11211)
# Clp0006I 62000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (11388)
# Clp0006I 63000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (25950)
# Clp0006I 64000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (11715)
# Clp0006I 65000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (46166)
# Clp0006I 66000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (42105)
# Clp0006I 67000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (42694)
# Clp0006I 68000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (43226)
# Clp0006I 69000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (43797)
# Clp0006I 70000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (49381)
# Clp0006I 71000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (12907)
# Clp0006I 72000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (28827)
# Clp0006I 73000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (13198)
# Clp0006I 74000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (13357)
# Clp0006I 75000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (13522)
# Clp0006I 76000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (13704)
# Clp0006I 77000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (13867)
# Clp0006I 78000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (54457)
# Clp0006I 79000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (14219)
# Clp0006I 80000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (14376)
# Clp0006I 81000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (14545)
# Clp0006I 82000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (14693)
# Clp0006I 83000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (14857)
# Clp0006I 84000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (15033)
# Clp0006I 85000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (58797)
# Clp0006I 86000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (53177)
# Clp0006I 87000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (60073)
# Clp0006I 88000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (15742)
# Clp0006I 89000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (15946)
# Clp0006I 90000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (55444)
# Clp0006I 91000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (62719)
# Clp0006I 92000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (16504)
# Clp0006I 93000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (16668)
# Clp0006I 94000  Obj 0 Primal inf 64.346371 (495) Dual inf 5.6236277e+14 (57721)
# Clp0029I End of values pass after 94794 iterations
# Clp0006I 94794  Obj 0.0025 Primal inf 53.174339 (497) Dual inf 2.3254692e+15 (92799)
# Clp0029I End of values pass after 94887 iterations
# Clp0006I 94887  Obj 0.0025 Primal inf 53.039073 (530) Dual inf 2.2972492e+15 (92707)
# Clp0006I 95887  Obj 0.0025002377 Primal inf 0.11865581 (10) Dual inf 2.8886926e+13 (556)
# Clp0006I 96887  Obj 0.0024977222
# Clp0006I 97887  Obj 0.0024887563
# Clp0006I 98867  Obj 0.0024887563
# Clp0006I 98967  Obj 0.0024886189
# Clp0006I 99092  Obj 0.0024877216
# Clp0000I Optimal - objective value 0.0024877216
# Clp0006I 0  Obj 0.0024877216 Primal inf 0.00010427626 (940) Dual inf 6.5046402e+12 (63344)
# Clp0029I End of values pass after 51 iterations
# Clp0006I 51  Obj 0.0024877219 Dual inf 0.028506341 (62413)
# Clp0006I 251  Obj 0.0024868765 Dual inf 0.0026920789 (8769)
# Clp0006I 451  Obj 0.0024861471
# Clp0006I 651  Obj 0.0024858009
# Clp0006I 851  Obj 0.0024853145
# Clp0006I 1051  Obj 0.0024849307
# Clp0006I 1251  Obj 0.0024845478
# Clp0000I Optimal - objective value 0.0024845478
# Clp0032I Optimal objective 0.002484547763 - 100343 iterations time 134.122, Presolve 0.49
# Clp0006I 0  Obj 0.0024845478 Dual inf 0.00049307867 (1296)
# Clp0006I 0  Obj 0.0024845478 Dual inf 0.00049307867 (1296)
# Clp0006I 200  Obj 0.0024844667 Dual inf 0.00018006194 (1226)
# Clp0006I 238  Obj 0.0024844667 Dual inf 0.00018006194 (1226)
# Clp0006I 257  Obj 0.0024844603 Dual inf 0.00021088811 (1314)
# Clp0006I 281  Obj 0.0024844537 Dual inf 0.00011475249 (384)
# Clp0006I 308  Obj 0.0024846083 Dual inf 4.3050442 (2809)
# Clp0006I 338  Obj 0.0024844356
# Clp0006I 376  Obj 0.0024844206
# Clp0006I 424  Obj 0.0024844091
# Clp0006I 484  Obj 0.002484374
# Clp0006I 559  Obj 0.002484374
# Clp0000I Optimal - objective value 0.002484374
# Cbc0012I Integer solution of 0.0026787841 found by Couenne Rounding NLP after 0 iterations and 0 nodes (29.03 seconds)
# NLP Heuristic: time limit reached.
# Clp0006I 0  Obj 0.002484374 Dual inf 0.0012810545 (1804)
# Clp0006I 0  Obj 0.002484374 Dual inf 0.0012810545 (1804)
# Clp0006I 200  Obj 0.0024843278 Dual inf 9.3750505e-05 (895)
# Clp0006I 400  Obj 0.0024842895
# Clp0006I 600  Obj 0.0024842863
# Clp0006I 800  Obj 0.0024842863
# Clp0006I 1000  Obj 0.0024842855
# Clp0006I 1200  Obj 0.0024842831
# Clp0000I Optimal - objective value 0.0024842831
# Optimality Based BT: 0 improved bounds
# Probing: 0 improved bounds
# NLP Heuristic: no solution.
# Cbc0031I 18 added rows had average density of 2
# Cbc0013I At root node, 18 cuts changed objective from 0.0024842831 to 0.0024842831 in 6 passes
# Cbc0014I Cut generator 0 (Couenne convexifier cuts) - 52 row cuts average 2.0 elements, 1 column cuts (1 active)
# Cbc0010I After 0 nodes, 1 on tree, 0.0026787841 best solution, best possible 0.0024842831 (3037.72 seconds)
# Optimality Based BT: 1 improved bounds
# Optimality Based BT: 0 improved bounds
# Optimality Based BT: 0 improved bounds
# Optimality Based BT: 0 improved bounds
# Optimality Based BT: 0 improved bounds
# Optimality Based BT: 1 improved bounds
# Cbc0010I After 100 nodes, 50 on tree, 0.0026787841 best solution, best possible 0.0024842831 (25090.37 seconds)
# Cbc0010I After 200 nodes, 100 on tree, 0.0026787841 best solution, best possible 0.0024842831 (26272.11 seconds)
# Cbc0010I After 300 nodes, 150 on tree, 0.0026787841 best solution, best possible 0.0024842831 (27732.33 seconds)
# Cbc0010I After 400 nodes, 200 on tree, 0.0026787841 best solution, best possible 0.0024842831 (28888.89 seconds)
# Cbc0010I After 500 nodes, 250 on tree, 0.0026787841 best solution, best possible 0.0024842831 (30544.98 seconds)
# Cbc0010I After 600 nodes, 300 on tree, 0.0026787841 best solution, best possible 0.0024842831 (32043.70 seconds)
# Cbc0010I After 700 nodes, 350 on tree, 0.0026787841 best solution, best possible 0.0024842831 (32992.54 seconds)
# Cbc0010I After 800 nodes, 400 on tree, 0.0026787841 best solution, best possible 0.0024842831 (34010.95 seconds)
# Cbc0010I After 900 nodes, 450 on tree, 0.0026787841 best solution, best possible 0.0024842831 (34947.66 seconds)
# Cbc0010I After 1000 nodes, 500 on tree, 0.0026787841 best solution, best possible 0.0024842831 (36336.79 seconds)
# Cbc0010I After 1100 nodes, 550 on tree, 0.0026787841 best solution, best possible 0.0024842831 (38117.12 seconds)
# Cbc0010I After 1200 nodes, 600 on tree, 0.0026787841 best solution, best possible 0.0024842831 (40258.17 seconds)
# Optimality Based BT: 1 improved bounds
# Optimality Based BT: 0 improved bounds
# Cbc0010I After 1300 nodes, 647 on tree, 0.0026787841 best solution, best possible 0.0024842831 (49604.26 seconds)
# Cbc0010I After 1400 nodes, 697 on tree, 0.0026787841 best solution, best possible 0.0024842831 (54419.93 seconds)
# Cbc0010I After 1500 nodes, 747 on tree, 0.0026787841 best solution, best possible 0.0024842831 (57923.94 seconds)
# Cbc0010I After 1600 nodes, 797 on tree, 0.0026787841 best solution, best possible 0.0024842831 (58894.53 seconds)
# Cbc0010I After 1700 nodes, 847 on tree, 0.0026787841 best solution, best possible 0.0024842831 (61180.83 seconds)
# Cbc0010I After 1800 nodes, 897 on tree, 0.0026787841 best solution, best possible 0.0024842831 (62319.22 seconds)
# Cbc0010I After 1900 nodes, 947 on tree, 0.0026787841 best solution, best possible 0.0024842831 (63773.95 seconds)
# Cbc0010I After 2000 nodes, 997 on tree, 0.0026787841 best solution, best possible 0.0024842831 (65298.45 seconds)
# Cbc0010I After 2100 nodes, 1047 on tree, 0.0026787841 best solution, best possible 0.0024842831 (66727.86 seconds)
# Cbc0010I After 2200 nodes, 1097 on tree, 0.0026787841 best solution, best possible 0.0024842831 (67738.61 seconds)
# Cbc0010I After 2300 nodes, 1147 on tree, 0.0026787841 best solution, best possible 0.0024842831 (70281.56 seconds)
# Cbc0010I After 2400 nodes, 1197 on tree, 0.0026787841 best solution, best possible 0.0024842831 (72138.33 seconds)
# Cbc0010I After 2500 nodes, 1247 on tree, 0.0026787841 best solution, best possible 0.0024842831 (74428.62 seconds)
# Cbc0010I After 2600 nodes, 1297 on tree, 0.0026787841 best solution, best possible 0.0024842831 (76776.67 seconds)
# Cbc0010I After 2700 nodes, 1345 on tree, 0.0026787841 best solution, best possible 0.0024842831 (80694.86 seconds)
# Cbc0010I After 2800 nodes, 1395 on tree, 0.0026787841 best solution, best possible 0.0024842831 (84859.11 seconds)
# Cbc0010I After 2900 nodes, 1445 on tree, 0.0026787841 best solution, best possible 0.0024842829 (86476.03 seconds)
# Cbc0010I After 3000 nodes, 1495 on tree, 0.0026787841 best solution, best possible 0.0024842829 (87494.31 seconds)
# Cbc0010I After 3100 nodes, 1545 on tree, 0.0026787841 best solution, best possible 0.0024842831 (89041.04 seconds)
# Cbc0010I After 3200 nodes, 1595 on tree, 0.0026787841 best solution, best possible 0.0024842831 (90341.63 seconds)
# Cbc0010I After 3300 nodes, 1645 on tree, 0.0026787841 best solution, best possible 0.0024842831 (91635.96 seconds)
# Cbc0010I After 3400 nodes, 1695 on tree, 0.0026787841 best solution, best possible 0.0024842831 (92653.21 seconds)
# Cbc0010I After 3500 nodes, 1745 on tree, 0.0026787841 best solution, best possible 0.0024842831 (93675.87 seconds)
# Cbc0010I After 3600 nodes, 1795 on tree, 0.0026787841 best solution, best possible 0.0024842831 (95281.84 seconds)
# Cbc0010I After 3700 nodes, 1845 on tree, 0.0026787841 best solution, best possible 0.0024842831 (97153.27 seconds)
# Cbc0010I After 3800 nodes, 1895 on tree, 0.0026787841 best solution, best possible 0.0024842831 (99412.99 seconds)
# Optimality Based BT: 0 improved bounds
# Cbc0010I After 3900 nodes, 1939 on tree, 0.0026787841 best solution, best possible 0.0024842831 (104235.08 seconds)
# Cbc0010I After 4000 nodes, 1989 on tree, 0.0026787841 best solution, best possible 0.0024842831 (106879.04 seconds)
# Cbc0010I After 4100 nodes, 2039 on tree, 0.0026787841 best solution, best possible 0.0024842831 (107729.45 seconds)
# Cbc0010I After 4200 nodes, 2089 on tree, 0.0026787841 best solution, best possible 0.0024842831 (108798.00 seconds)
# Cbc0010I After 4300 nodes, 2139 on tree, 0.0026787841 best solution, best possible 0.0024842831 (110138.31 seconds)
# Cbc0010I After 4400 nodes, 2189 on tree, 0.0026787841 best solution, best possible 0.0024842831 (111302.16 seconds)
# Cbc0010I After 4500 nodes, 2239 on tree, 0.0026787841 best solution, best possible 0.0024842831 (112836.01 seconds)
# Cbc0010I After 4600 nodes, 2289 on tree, 0.0026787841 best solution, best possible 0.0024842831 (114040.50 seconds)
# Cbc0010I After 4700 nodes, 2339 on tree, 0.0026787841 best solution, best possible 0.0024842831 (114970.86 seconds)
# Cbc0010I After 4800 nodes, 2389 on tree, 0.0026787841 best solution, best possible 0.0024842831 (115844.67 seconds)
# Cbc0010I After 4900 nodes, 2439 on tree, 0.0026787841 best solution, best possible 0.0024842831 (117559.30 seconds)
# Cbc0010I After 5000 nodes, 2489 on tree, 0.0026787841 best solution, best possible 0.0024842831 (119389.63 seconds)
# Cbc0010I After 5100 nodes, 2539 on tree, 0.0026787841 best solution, best possible 0.0024842831 (121535.32 seconds)
# Cbc0010I After 5200 nodes, 2586 on tree, 0.0026787841 best solution, best possible 0.0024842831 (124220.20 seconds)
# Cbc0010I After 5300 nodes, 2636 on tree, 0.0026787841 best solution, best possible 0.0024842831 (125711.63 seconds)
# Cbc0010I After 5400 nodes, 2686 on tree, 0.0026787841 best solution, best possible 0.0024842831 (127470.27 seconds)
# Cbc0010I After 5500 nodes, 2736 on tree, 0.0026787841 best solution, best possible 0.0024842831 (128498.69 seconds)
# Cbc0010I After 5600 nodes, 2786 on tree, 0.0026787841 best solution, best possible 0.0024842831 (129484.01 seconds)
# Cbc0010I After 5700 nodes, 2836 on tree, 0.0026787841 best solution, best possible 0.0024842831 (130461.14 seconds)
# Cbc0010I After 5800 nodes, 2886 on tree, 0.0026787841 best solution, best possible 0.0024842831 (131974.11 seconds)
# Cbc0010I After 5900 nodes, 2936 on tree, 0.0026787841 best solution, best possible 0.0024842831 (133762.78 seconds)
# Cbc0010I After 6000 nodes, 2986 on tree, 0.0026787841 best solution, best possible 0.0024842831 (135822.36 seconds)
# Cbc0010I After 6100 nodes, 3030 on tree, 0.0026787841 best solution, best possible 0.0024842831 (138032.15 seconds)
# Cbc0010I After 6200 nodes, 3080 on tree, 0.0026787841 best solution, best possible 0.0024842831 (142460.97 seconds)
# Cbc0010I After 6300 nodes, 3130 on tree, 0.0026787841 best solution, best possible 0.0024842831 (143650.29 seconds)
# Cbc0010I After 6400 nodes, 3180 on tree, 0.0026787841 best solution, best possible 0.0024842831 (147328.97 seconds)
# Cbc0010I After 6500 nodes, 3230 on tree, 0.0026787841 best solution, best possible 0.0024842831 (149169.87 seconds)
# Cbc0010I After 6600 nodes, 3280 on tree, 0.0026787841 best solution, best possible 0.0024842831 (150212.79 seconds)
# Cbc0010I After 6700 nodes, 3330 on tree, 0.0026787841 best solution, best possible 0.0024842831 (151554.42 seconds)
# Cbc0010I After 6800 nodes, 3380 on tree, 0.0026787841 best solution, best possible 0.0024842831 (152565.38 seconds)
# Cbc0010I After 6900 nodes, 3430 on tree, 0.0026787841 best solution, best possible 0.0024842831 (153589.97 seconds)
# Cbc0010I After 7000 nodes, 3480 on tree, 0.0026787841 best solution, best possible 0.0024842831 (154568.03 seconds)
# Cbc0010I After 7100 nodes, 3530 on tree, 0.0026787841 best solution, best possible 0.0024842831 (156312.65 seconds)
# Cbc0010I After 7200 nodes, 3580 on tree, 0.0026787841 best solution, best possible 0.0024842831 (158307.29 seconds)
# Cbc0010I After 7300 nodes, 3629 on tree, 0.0026787841 best solution, best possible 0.0024842831 (160535.48 seconds)
# Cbc0010I After 7400 nodes, 3676 on tree, 0.0026787841 best solution, best possible 0.0024842831 (163647.93 seconds)
#   Signal handler called from  /opt/anaconda/anaconda3/lib/python3.6/subprocess.py _try_wait 1386
#   Waiting...
#   Signaled process 75501 with signal 2
#   Signal handler called from  /opt/anaconda/anaconda3/lib/python3.6/threading.py _wait_for_tstate_lock 1072
#   Waiting...
#
#   Signal handler is busy.  Aborting.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: -2
# /opt/anaconda/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2918: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
